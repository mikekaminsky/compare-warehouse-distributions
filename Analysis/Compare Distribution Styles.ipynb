# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
sns.set(style="whitegrid")
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %% [markdown]
# # Redshift

# %%
data = pd.read_csv('../data/redshift_results.csv')
data['run_group'] = ['first' if x == 1 else 'subsequent' for x in data['nth']]

# %%
cluster_info = data[['cluster_type', 'node_type', 'run_group']].drop_duplicates()

# %%
for index, row in cluster_info.iterrows():
    cluster_type = row['cluster_type']
    node_type = row['node_type']
    run_group = row['run_group']
    
    sub = data[(data['cluster_type'] == cluster_type) & 
               (data['node_type'] == node_type) & 
               (data['run_group'] == run_group)]
    
    plt.figure(figsize=(16, 6))
    g = sns.barplot(y="time", x="test", hue="style",data=sub, palette="Set3")
    g.set_xticklabels(g.get_xticklabels(), rotation=45, ha="right")
    g.set(xlabel='Query', ylabel='Execution Time (seconds)')
    g.set_title('Redshift Query Time on {} Run {}:{}'.format(run_group.title(), node_type, cluster_type))
    g.figure.savefig("images/{}_{}_{}.png".format(node_type,cluster_type,run_group))
# Out:
# /Users/michaelkaminsky/.virtualenvs/compare-warehouse-distributions/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
avg = data.groupby(["cluster_type","node_type","run_group","style","test"]).agg({'time': 'mean'}).reset_index()
avg = avg.pivot_table(
    index=['test', 'cluster_type', 'run_group','node_type'], 
    columns='style',  
    values='time').reset_index()
avg['improvement'] = 1- avg['obt'] / avg['star']
avg
# Out:
# style                           test cluster_type   run_group    node_type  \
# 0                  01_simple_groupby   multi-node       first  dc2.8xlarge
# 1                  01_simple_groupby   multi-node  subsequent  dc2.8xlarge
# 2                  01_simple_groupby  single-node       first    dc2.large
# 3                  01_simple_groupby  single-node  subsequent    dc2.large
# 4       02_cross_table_multi_groupby   multi-node       first  dc2.8xlarge
# 5       02_cross_table_multi_groupby   multi-node  subsequent  dc2.8xlarge
# 6       02_cross_table_multi_groupby  single-node       first    dc2.large
# 7       02_cross_table_multi_groupby  single-node  subsequent    dc2.large
# 8        03_high_cardinality_groupby   multi-node       first  dc2.8xlarge
# 9        03_high_cardinality_groupby   multi-node  subsequent  dc2.8xlarge
# 10       03_high_cardinality_groupby  single-node       first    dc2.large
# 11       03_high_cardinality_groupby  single-node  subsequent    dc2.large
# 12                04_window_function   multi-node       first  dc2.8xlarge
# 13                04_window_function   multi-node  subsequent  dc2.8xlarge
# 14                04_window_function  single-node       first    dc2.large
# 15                04_window_function  single-node  subsequent    dc2.large
# 16                    05_date_window   multi-node       first  dc2.8xlarge
# 17                    05_date_window   multi-node  subsequent  dc2.8xlarge
# 18                    05_date_window  single-node       first    dc2.large
# 19                    05_date_window  single-node  subsequent    dc2.large
# 20                  06_date_window_2   multi-node       first  dc2.8xlarge
# 21                  06_date_window_2   multi-node  subsequent  dc2.8xlarge
# 22                  06_date_window_2  single-node       first    dc2.large
# 23                  06_date_window_2  single-node  subsequent    dc2.large
# 24                   07_wait_buy_why   multi-node       first  dc2.8xlarge
# 25                   07_wait_buy_why   multi-node  subsequent  dc2.8xlarge
# 26                   07_wait_buy_why  single-node       first    dc2.large
# 27                   07_wait_buy_why  single-node  subsequent    dc2.large
# 28                 08_more_addresses   multi-node       first  dc2.8xlarge
# 29                 08_more_addresses   multi-node  subsequent  dc2.8xlarge
# 30                 08_more_addresses  single-node       first    dc2.large
# 31                 08_more_addresses  single-node  subsequent    dc2.large
# 32     09_simple_groupby_with_filter   multi-node       first  dc2.8xlarge
# 33     09_simple_groupby_with_filter   multi-node  subsequent  dc2.8xlarge
# 34     09_simple_groupby_with_filter  single-node       first    dc2.large
# 35     09_simple_groupby_with_filter  single-node  subsequent    dc2.large
# 36             10_simple_groupby_sum   multi-node       first  dc2.8xlarge
# 37             10_simple_groupby_sum   multi-node  subsequent  dc2.8xlarge
# 38             10_simple_groupby_sum  single-node       first    dc2.large
# 39             10_simple_groupby_sum  single-node  subsequent    dc2.large
#
# style         obt        star  improvement
# 0        1.815780    0.228969    -6.930241
# 1        0.092790    0.152093     0.389908
# 2       54.917727  124.442602     0.558690
# 3       21.407986   34.816606     0.385121
# 4        1.995526    6.416618     0.689007
# 5        0.111129    0.158618     0.299394
# 6      222.601936  228.341397     0.025135
# 7       59.541731   67.629292     0.119587
# 8        3.344764    7.509536     0.554598
# 9        0.105997    0.178456     0.406034
# 10      28.297559   45.081292     0.372299
# 11      24.553810   34.774978     0.293923
# 12       5.489092    9.852450     0.442870
# 13       0.106982    0.118012     0.093461
# 14      91.757749   83.165070    -0.103321
# 15      57.597729   49.056997    -0.174098
# 16       1.862336    8.394212     0.778140
# 17       0.104392    0.113166     0.077536
# 18      30.814896   64.003558     0.518544
# 19      25.411703   36.912945     0.311577
# 20       1.797005    8.023880     0.776043
# 21       0.113994    0.130547     0.126798
# 22      31.842538   45.862764     0.305700
# 23      26.180160   36.816745     0.288906
# 24       5.151968    9.285627     0.445167
# 25       0.110460    0.118581     0.068487
# 26      32.957799   49.110390     0.328904
# 27      26.056381   35.053402     0.256666
# 28       4.574785    8.902828     0.486143
# 29       0.143106    0.263568     0.457045
# 30      72.463849  102.849629     0.295439
# 31      84.870293  107.569183     0.211017
# 32       1.866106    2.002391     0.068061
# 33       0.096041    0.165460     0.419549
# 34      15.116302   25.504018     0.407297
# 35      13.188478   26.651414     0.505149
# 36       1.790322    4.447390     0.597444
# 37       0.093295    0.148736     0.372746
# 38      23.774908   40.919077     0.418977
# 39      24.298109   35.562535     0.316750

# %%
avg.groupby(['cluster_type', 'node_type', 'run_group']).mean()
# Out:
# style                                      obt       star  improvement
# cluster_type node_type   run_group
# multi-node   dc2.8xlarge first        2.968768   6.506390    -0.209277
#                          subsequent   0.107819   0.154724     0.271096
# single-node  dc2.large   first       60.454526  80.927980     0.312767
#                          subsequent  36.310638  46.484410     0.251460

# %%
for index, row in cluster_info.iterrows():
    cluster_type = row['cluster_type']
    node_type = row['node_type']
    run_group = row['run_group']
    
    avg_sub = avg[(avg['cluster_type'] == cluster_type) & 
           (avg['node_type'] == node_type) & 
           (avg['run_group'] == run_group)]


    plt.figure(figsize=(16, 6))
    g = sns.barplot(y="improvement", x="test", data=avg_sub, color="steelblue")    
    g.set_xticklabels(g.get_xticklabels(), rotation=45, ha="right")
    g.set(xlabel='Query', ylabel='% Improvement Using One Big Table')
    vals = g.get_yticks()
    g.set_yticklabels(['{:,.2%}'.format(x) for x in vals])
    g.set_title('Average Improvement on {} Run Using One Big Table {}:{}'.format(run_group.title(),node_type, cluster_type))

# %% [markdown]
# # Snowflake

# %%
data = pd.read_csv('../data/snowflake_results.csv')

# %%
plt.figure(figsize=(16, 6))
g = sns.barplot(y="time", x="test", hue="style",data=data, palette="Set2")
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha="right")
g.set(xlabel='Query', ylabel='Execution Time (seconds)')
g.set_title('Snowflake Query Time')
g.figure.savefig("images/snowflake.png")

# %%
avg = data.groupby(["style","test"]).agg({'time': 'mean'}).reset_index()
avg = avg.pivot(index='test', columns='style',  values='time').reset_index()
avg['improvement'] = 1- avg['obt'] / avg['star']
avg
# Out:
# style                           test       obt      star  improvement
# 0                  01_simple_groupby  0.274145  0.281867     0.027394
# 1       02_cross_table_multi_groupby  0.216420  0.314983     0.312914
# 2        03_high_cardinality_groupby  0.296119  0.279311    -0.060177
# 3                 04_window_function  0.314709  0.253145    -0.243192
# 4                     05_date_window  0.237586  0.237141    -0.001875
# 5                   06_date_window_2  0.283755  0.360702     0.213326
# 6                    07_wait_buy_why  0.300499  0.230887    -0.301499
# 7                  08_more_addresses  0.913945  1.210662     0.245086
# 8      09_simple_groupby_with_filter  0.261481  0.518490     0.495687
# 9              10_simple_groupby_sum  0.283987  0.334408     0.150779

# %%
avg['improvement'].mean()
# Out:
# 0.08384431218733558

# %% [markdown]
# # Bigquery

# %%
data = pd.read_csv('../data/bigquery_results.csv')

# %%
plt.figure(figsize=(16, 6))
g = sns.barplot(y="time", x="test", hue="style",data=data, palette="Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha="right")
g.set(xlabel='Query', ylabel='Execution Time (seconds)')
g.set_title('Bigquery Query Time')
g.figure.savefig("images/bigquery.png")

# %%
avg = data.groupby(["style","test"]).agg({'time': 'mean'}).reset_index()
avg = avg.pivot(index='test', columns='style',  values='time').reset_index()
avg['improvement'] = 1- avg['obt'] / avg['star']
avg
# Out:
# style                           test       obt       star  improvement
# 0                  01_simple_groupby  2.014780   5.607346     0.640689
# 1       02_cross_table_multi_groupby  2.230648   7.157923     0.688367
# 2        03_high_cardinality_groupby  2.352157   6.305828     0.626987
# 3                 04_window_function  3.053729   4.039087     0.243956
# 4                     05_date_window  2.925423   4.150906     0.295233
# 5                   06_date_window_2  3.724583   4.438778     0.160899
# 6                    07_wait_buy_why  3.347254   4.519673     0.259403
# 7                  08_more_addresses  4.296247  14.886561     0.711401
# 8      09_simple_groupby_with_filter  1.995187   5.766738     0.654018
# 9              10_simple_groupby_sum  2.473920   6.001119     0.587757

# %%
avg['improvement'].mean()
# Out:
# 0.48687093400750736
